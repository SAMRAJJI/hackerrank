# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'aVeryBigSum' function below.
#
# The function is expected to return a LONG_INTEGER.
# The function accepts LONG_INTEGER_ARRAY ar as parameter.
#

def aVeryBigSum(ar):
    return sum(ar)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    ar_count = int(input().strip())

    ar = list(map(int, input().rstrip().split()))

    result = aVeryBigSum(ar)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
def solveMeFirst(a,b):
	return a+b

num1 = int(input())
num2 = int(input())
res = solveMeFirst(num1,num2)
print(res)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'compareTriplets' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts following parameters:
#  1. INTEGER_ARRAY a
#  2. INTEGER_ARRAY b
#

def compareTriplets(a, b):
    alice=0
    bob=0
    for i in range(len(a)):
        if a[i]>b[i]:
            alice+=1
        elif a[i]==b[i]:
            continue
        else:
            bob+=1
    return alice,bob

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    a = list(map(int, input().rstrip().split()))

    b = list(map(int, input().rstrip().split()))

    result = compareTriplets(a, b)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
import math
import os
import random
import re
import sys

def miniMaxSum(arr):
    arr.sort()  # Sort the array in ascending order
    min_sum = sum(arr[:4])  # Sum of the first 4 smallest numbers
    max_sum = sum(arr[1:])  # Sum of the last 4 largest numbers
    print(min_sum, max_sum)
            

if __name__ == '__main__':

    arr = list(map(int, input().rstrip().split()))

    miniMaxSum(arr)

# %%
import math
import os
import random
import re
import sys

def kangaroo(x1, v1, x2, v2):
    if v1 > v2 and (x1 - x2) % (v1 - v2) == 0:
        return 'YES'
    return 'NO'
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'diagonalDifference' function below.
#
# The function is expected to return an INTEGER.
# The function accepts 2D_INTEGER_ARRAY arr as parameter.
#

def diagonalDifference(arr):
    num=0
    m=0
    n=len(arr)
    for i in range(n):
        num+= arr[i][i]
        m+= arr[i][n-i-1]
    return abs(num-m)
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    result = diagonalDifference(arr)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
def plusMinus(arr):
    n=len(arr)
    pos=[]
    neg=[]
    zer=[]
    for num in arr:
        if num > 0:
            pos.append(num)
        elif num < 0:
            neg.append(num)
        else:
            zer.append(num)
    print(f"{len(pos)/n:.5f}")
    print(f"{len(neg)/n:.5f}")
    print(f"{len(zer)/n:.5f}")

if __name__ == '__main__':

    arr = [-4, 3, -9, 0, 4, 1]

    plusMinus(arr)
# Out:
# 0.50000
# 0.33333
# 0.16667

# %%
def staircase(n):
    for i in range(1,n+1):
        print(" "*(n-i)+"#"*(i))
if __name__ == '__main__':
    n = int(input().strip())

    staircase(n)
# Out:
#     #
#    ##
#   ###
#  ####
# #####

# %%
from datetime import datetime

def timeConversion(s):
    railway_time = datetime.strptime(s, "%I:%M:%S%p").strftime("%H:%M:%S")
    return railway_time

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = timeConversion(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
from collections import Counter

def birthdayCakeCandles(candles):
    a = Counter(candles)
    return max(a.values())
    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


def gradingStudents(grades):
    rounded_grades = []  # Store the final rounded grades
    for i in grades:
        if i < 38:
            rounded_grades.append(i)  # No rounding if below 38
        else:
            nextval = (i // 5 + 1) * 5  # Calculate next multiple of 5
            if nextval - i < 3:
                rounded_grades.append(nextval)  # Round up
            else:
                rounded_grades.append(i)  # Keep the same grade
    return rounded_grades
        
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    grades_count = int(input().strip())

    grades = []

    for _ in range(grades_count):
        grades_item = int(input().strip())
        grades.append(grades_item)

    result = gradingStudents(grades)

    fptr.write('\n'.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
def countApplesAndOranges(s, t, a, b, apples, oranges):
    apple_count = 0
    orange_count = 0
    
    for d in apples:
        pos = a + d
        if s <= pos <= t:
            apple_count += 1
    
    for d in oranges:
        pos = b + d
        if s <= pos <= t:
            orange_count += 1
    print(apple_count)
    print(orange_count)

if __name__ == '__main__':
    first_multiple_input = input().rstrip().split()

    s = int(first_multiple_input[0])

    t = int(first_multiple_input[1])

    second_multiple_input = input().rstrip().split()

    a = int(second_multiple_input[0])

    b = int(second_multiple_input[1])

    third_multiple_input = input().rstrip().split()

    m = int(third_multiple_input[0])

    n = int(third_multiple_input[1])

    apples = list(map(int, input().rstrip().split()))

    oranges = list(map(int, input().rstrip().split()))

    countApplesAndOranges(s, t, a, b, apples, oranges)

# %%
def breakingRecords(scores):
    mini=0
    maxi=0
    def_val_max=scores[0]
    def_val_min=scores[0]
    for i in range (1, len(scores)):
        if scores[i]>def_val_max:
            maxi+=1
            def_val_max=scores[i]
        if scores[i]< def_val_min:
            mini+=1
            def_val_min=scores[i]
    return maxi, mini
            
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    scores = list(map(int, input().rstrip().split()))

    result = breakingRecords(scores)

    fptr.write(' '.join(map(str, result)))
    fptr.write('\n')

    fptr.close()

# %%
def birthday(s, d, m):
    count = 0
    for i in range(len(s) - m + 1):  # Ensure subarray of size m exists
        if sum(s[i:i + m]) == d:  # Check if sum of subarray equals d
            count += 1
    return count
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    s = list(map(int, input().rstrip().split()))

    first_multiple_input = input().rstrip().split()

    d = int(first_multiple_input[0])

    m = int(first_multiple_input[1])

    result = birthday(s, d, m)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


def getTotalX(a, b):
    def gcd(x, y):
        while y:
            x, y = y, x % y
        return x

    def lcm(x, y):
        return x * y // gcd(x, y)

    # Find LCM of array a
    lcm_a = a[0]
    for num in a[1:]:
        lcm_a = lcm(lcm_a, num)

    # Find GCD of array b
    gcd_b = b[0]
    for num in b[1:]:
        gcd_b = gcd(gcd_b, num)

    # Count numbers that are multiples of lcm_a and divisors of gcd_b
    count = 0
    multiple = lcm_a
    while multiple <= gcd_b:
        if gcd_b % multiple == 0:
            count += 1
        multiple += lcm_a

    return count
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0])

    m = int(first_multiple_input[1])

    arr = list(map(int, input().rstrip().split()))

    brr = list(map(int, input().rstrip().split()))

    total = getTotalX(arr, brr)

    fptr.write(str(total) + '\n')

    fptr.close()

# %%
def bonAppetit(bill, k, b):
    bill.pop(k)
    a = sum(bill)/2
    if a == b:
        print("Bon Appetit")
    else:
        print((int(b-a)))

if __name__ == '__main__':
    first_multiple_input = input().rstrip().split()

    n = int(first_multiple_input[0])

    k = int(first_multiple_input[1])

    bill = list(map(int, input().rstrip().split()))

    b = int(input().strip())

    bonAppetit(bill, k, b)

# %%
from collections import Counter
def sockMerchant(n, ar):
    val=0
    df=Counter(ar)
    for i,j in df.items():
        val+=j//2
    return val

# %%
def pageCount(n, p):
    f_turns = int(p/2)
    b_turns = int((n-p+1)/2) if (n%2==0) else int((n-p)/2)

    return min(f_turns,b_turns)
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    p = int(input().strip())

    result = pageCount(n, p)

# %%
def countingValleys(steps, path):
    sea_level = 0
    valleys = 0
    elevation = 0  # Track current elevation

    for step in path:
        if step == "U":
            elevation += 1
        elif step == "D":
            elevation -= 1

        # A valley is counted when we move **up to sea level** from below
        if elevation == 0 and step == "U":
            valleys += 1

    return valleys 

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    steps = int(input().strip())

    path = input()

    result = countingValleys(steps, path)

    fptr.write(str(result) + '\n')

    fptr.close()
